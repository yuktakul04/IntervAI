# %%
## Import required libraries
import numpy as np
import pandas as pd
## Upload dataset
import seaborn as sns
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a0f19acf-c2e2-4739-8c5d-fb9f3b310a4d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0f19acf-c2e2-4739-8c5d-fb9f3b310a4d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
## Read a .csv file to pandas dataframe
df = pd.read_csv('new-dataset.csv')
## Read a .json file to pandas dataframe
# df = pd.read_json('Final (1).json')
## Read an excel file to pandas dataframe
# df = pd.read_excel('Final (1).xlsx')

# %%
## Read a .csv file to a dataframe with delimiter as space or tab:
df =  pd.read_csv('Final_Dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-940b2682c41c> in <cell line: 2>()
#       1 ## Read a .csv file to a dataframe with delimiter as space or tab:
# ----> 2 df =  pd.read_csv('Final_Dataset.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#              Code
# count  327.000000
# mean   102.000000
# std      2.133576
# min     99.000000
# 25%    100.000000
# 50%    103.000000
# 75%    103.000000
# max    106.000000

# %%
df.head(5) # returns first '5' rows of the dataframe
df.tail(5) # returns last '5' rows of the dataframe
# Out:
#       Code                                           Question  \
# 325  106.0  : What is the difference between heat map and ...
# 326  106.0                : Why is it important to tidy data?
# 327  106.0           : What are the main features of Tableau?
# 328  106.0  : What are the key components or grammar for t...
# 329  106.0  : Explain Bar charts in Tableau. What are the ...
#
#                                                 Answer
# 325  Heat maps and treemaps are two different types...
# 326  Tidying data refers to the process of organizi...
# 327  The main features of Tableau include:\nData Co...
# 328  The key components or grammar for visualizatio...
# 329  Bar charts in Tableau are used to visualize ca...

# %%
df.columns
# Out:
# Index(['Code', 'Question', 'Answer'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 327 entries, 0 to 329
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Code      327 non-null    float64
#  1   Question  327 non-null    object
#  2   Answer    326 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 10.2+ KB

# %%
sns.countplot(y = 'Code', data= df, order= df['Code'].value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='Code'>

# %%
df1= df.copy()
df1['cleaned_resume']= ""
df1
# Out:
#       Code                                           Question  \
# 0     99.0  Are you willing to work extra hours when wrapp...
# 1     99.0            Tell me a few facts about our company.
# 2     99.0            Are you willing to travel or relocate?
# 3     99.0      Do you have any plans for further education?
# 4     99.0                Do you have a personal work style?
# ..     ...                                                ...
# 325  106.0  : What is the difference between heat map and ...
# 326  106.0                : Why is it important to tidy data?
# 327  106.0           : What are the main features of Tableau?
# 328  106.0  : What are the key components or grammar for t...
# 329  106.0  : Explain Bar charts in Tableau. What are the ...
#
#                                                 Answer cleaned_resume
# 0    Yes, I understand that meeting deadlines and d...
# 1    It's important to research the company beforeh...
# ...

# %%
import re
def clean_function(resumeText):
    resumeText = re.sub('http\S+\s*', ' ', resumeText)
    resumeText = re.sub('#\S+', '', resumeText)
    resumeText = re.sub('@\S+', '  ', resumeText)
    resumeText = re.sub(r'[^\x00-\x7f]',r' ', resumeText)
    resumeText = re.sub('\s+', ' ', resumeText)
    resumeText = re.sub("^[0-9]+", "", resumeText)
    resumeText = re.sub("^[:]", "", resumeText)
    resumeText = re.sub(r'[^\w\s]','',resumeText)

    return resumeText

# %%
df1['Question'] = df1['Question'].apply(lambda x: clean_function(x))
df1.head(10)
# Out:
#    Code                                           Question  \
# 0  99.0  Are you willing to work extra hours when wrapp...
# 1  99.0             Tell me a few facts about our company
# 2  99.0             Are you willing to travel or relocate
# 3  99.0       Do you have any plans for further education
# 4  99.0                 Do you have a personal work style
# 5  99.0  How did you find out about this job and did yo...
# 6  99.0                 Have you ever done volunteer work
# 7  99.0  What is one thing you hope to achieve in this ...
# 8  99.0  Are you independent or do you prefer working a...
# 9  99.0    How could you add value to our company culture
#
#                                               Answer cleaned_resume
# 0  Yes, I understand that meeting deadlines and d...
# 1  It's important to research the company beforeh...
# 2  This depends on your personal circumstances an...
# 3  Share your interest in continuous learning and...
# ...

# %%
df1= df1.drop(['cleaned_resume'], axis=1)

# %%
df1
# Out:
#       Code                                           Question  \
# 0     99.0  Are you willing to work extra hours when wrapp...
# 1     99.0             Tell me a few facts about our company
# 2     99.0             Are you willing to travel or relocate
# 3     99.0       Do you have any plans for further education
# 4     99.0                 Do you have a personal work style
# ..     ...                                                ...
# 325  106.0   What is the difference between heat map and t...
# 326  106.0                   Why is it important to tidy data
# 327  106.0              What are the main features of Tableau
# 328  106.0   What are the key components or grammar for th...
# 329  106.0   Explain Bar charts in Tableau What are the di...
#
#                                                 Answer
# 0    Yes, I understand that meeting deadlines and d...
# 1    It's important to research the company beforeh...
# 2    This depends on your personal circumstances an...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

def generate_word_cloud_word_count(dataframe, Question):
    # Extract the text data from the specified column
    text_data = ' '.join(dataframe['Question'].astype(str).tolist())

    # Tokenize the text into individual words
    words = text_data.split()

    # Count the frequency of each word
    word_counts = Counter(words)

    # Generate word cloud using word frequencies
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counts)

    # Display the word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

generate_word_cloud_word_count(df, 'question')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

def generate_word_cloud_word_count(dataframe, Answer):
    # Extract the text data from the specified column
    text_data = ' '.join(dataframe['Answer'].astype(str).tolist())

    # Tokenize the text into individual words
    words = text_data.split()

    # Count the frequency of each word
    word_counts = Counter(words)

    # Generate word cloud using word frequencies
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counts)

    # Display the word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

generate_word_cloud_word_count(df1, 'answer')

# %%
df.to_csv('/content/Final.csv', index=False)

# %%
'''def generate_word_cloud_sentence_lengths(dataframe, Question):
    # Convert column values to strings and join them
    text_data = ' '.join(dataframe['Question'].astype(str).tolist())

    # Split the text into sentences
    sentences = text_data.split('.')

    # Calculate the lengths of sentences
    sentence_lengths = [len(sentence.split()) for sentence in sentences]
    print("Sentence Lengths:", sentence_lengths)

    # Create a dictionary of sentence lengths and their frequencies
    sentence_length_counts = {length: sentence_lengths.count(length) for length in set(sentence_lengths)}
    print("Sentence Length Counts:", sentence_length_counts)

    # Generate word cloud using sentence length frequencies
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(sentence_length_counts)

    # Display the word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

generate_word_cloud_sentence_lengths(df, 'Question')'''
# Out:
# 'def generate_word_cloud_sentence_lengths(dataframe, Question):\n    # Convert column values to strings and join them\n    text_data = \' \'.join(dataframe[\'Question\'].astype(str).tolist())\n\n    # Split the text into sentences\n    sentences = text_data.split(\'.\')\n\n    # Calculate the lengths of sentences\n    sentence_lengths = [len(sentence.split()) for sentence in sentences]\n    print("Sentence Lengths:", sentence_lengths)\n\n    # Create a dictionary of sentence lengths and their frequencies\n    sentence_length_counts = {length: sentence_lengths.count(length) for length in set(sentence_lengths)}\n    print("Sentence Length Counts:", sentence_length_counts)\n\n    # Generate word cloud using sentence length frequencies\n    wordcloud = WordCloud(width=800, height=400, background_color=\'white\').generate_from_frequencies(sentence_length_counts)\n\n    # Display the word cloud\n    plt.figure(figsize=(10, 5))\n    plt.imshow(wordcloud, interpolation=\'bilinear\')\n    plt
# ...

# %%
# !pip install wordcloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# Read the CSV file
'''df1 = pd.read_csv('Final_Dataset-500.csv')'''

df1['Question'].fillna('', inplace=True)
df1['Answer'].fillna('', inplace=True)


# Perform lemmatization on a specific column
df1[['Question', 'Answer']] = df1[['Question', 'Answer']].applymap(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in nltk.word_tokenize(x)]))

# %%
'''print(df['lemmatized_text1','lemmatized_text2'])'''
for index, row in df1.iterrows():
    print(f"Lemmatized Text 1: {row['Question']}")
    print(f"Lemmatized Text 2: {row['Answer']}")
    print('---')  # Separator for readability
# Out:
# Lemmatized Text 1: Are you willing to work extra hour when wrapping up important project
# Lemmatized Text 2: Yes , I understand that meeting deadline and delivering quality work may require extra effort and time commitment . I am willing to go the extra mile when needed to ensure successful project completion .
# ---
# Lemmatized Text 1: Tell me a few fact about our company
# Lemmatized Text 2: It 's important to research the company beforehand to provide accurate fact . For example , you can mention the company 's mission , recent achievement , industry recognition , or it core products/services .
# ---
# Lemmatized Text 1: Are you willing to travel or relocate
# Lemmatized Text 2: This depends on your personal circumstance and the specific requirement of the job . You can express your willingness to consider travel or relocation if it aligns with your career goal and the opportunity at hand .
# ---
# Lemmatized Text 1: Do you have any plan for further education
# ...

# %%
print(df1)
# Out:
#       Code                                           Question  \
# 0     99.0  Are you willing to work extra hour when wrappi...
# 1     99.0               Tell me a few fact about our company
# 2     99.0              Are you willing to travel or relocate
# 3     99.0         Do you have any plan for further education
# 4     99.0                  Do you have a personal work style
# ..     ...                                                ...
# 325  106.0  What is the difference between heat map and tr...
# 326  106.0                   Why is it important to tidy data
# 327  106.0               What are the main feature of Tableau
# 328  106.0  What are the key component or grammar for the ...
# 329  106.0  Explain Bar chart in Tableau What are the diff...
#
#                                                 Answer
# 0    Yes , I understand that meeting deadline and d...
# 1    It 's important to research the company before...
# ...

# %%
num_columns = df1.shape[1]
num_rows = df1.shape[0]

print(f"Number of columns: {num_columns}")
print(f"Number of rows: {num_rows}")
# Out:
# Number of columns: 3
# Number of rows: 327

# %%
'''from nltk.stem import PorterStemmer'''
# Out:
# 'from nltk.stem import PorterStemmer'

# %%
'''stemmer = PorterStemmer()
for column in df.columns:
    # Check if the column contains text data
    if df[column].dtype == 'object':
        # Apply stemming to each cell in the column
        df[column] = df[column].apply(lambda x: ' '.join([stemmer.stem(word) for word in x.split()]))

# Print the modified dataset
df.head()'''
# Out:
# "stemmer = PorterStemmer()\nfor column in df.columns:\n    # Check if the column contains text data\n    if df[column].dtype == 'object':\n        # Apply stemming to each cell in the column\n        df[column] = df[column].apply(lambda x: ' '.join([stemmer.stem(word) for word in x.split()]))\n\n# Print the modified dataset\ndf.head()"

# %%
df1.to_csv('/content/new-dataset.csv', index=False)

# %%
df2= df.copy()

# %%
print(df2)
# Out:
#      Code                                           Question  \
# 0      99  Are you willing to work extra hour when wrappi...
# 1      99               Tell me a few fact about our company
# 2      99              Are you willing to travel or relocate
# 3      99         Do you have any plan for further education
# 4      99                  Do you have a personal work style
# ..    ...                                                ...
# 494   106  How can you effectively visualize categorical ...
# 495   106  Discuss the concept of data visualization ethi...
# 496   106  What are some technique for visualizing networ...
# 497   106  Explain the concept of data reduction in visua...
# 498   106  How can you effectively visualize data with ou...
#
#                                                 Answer
# 0    Yes , I understand that meeting deadline and d...
# 1    It 's important to research the company before...
# 2    This depends on your personal circumstance and...
# ...

# %%
df2 = df2.drop(['Answer','Code'], axis=1)

# %%
df2.to_csv('/content/qns-ds.csv', index=False)

# %%
print(df2)
# Out:
#                                               Question
# 0    Are you willing to work extra hour when wrappi...
# 1                 Tell me a few fact about our company
# 2                Are you willing to travel or relocate
# 3           Do you have any plan for further education
# 4                    Do you have a personal work style
# ..                                                 ...
# 494  How can you effectively visualize categorical ...
# 495  Discuss the concept of data visualization ethi...
# 496  What are some technique for visualizing networ...
# 497  Explain the concept of data reduction in visua...
# 498  How can you effectively visualize data with ou...
#
# [499 rows x 1 columns]

# %%
df3= df.copy()

# %%
df3 = df3.drop(['Question','Code'], axis=1)

# %%
print(df3)
# Out:
#                                                 Answer
# 0    Yes , I understand that meeting deadline and d...
# 1    It 's important to research the company before...
# 2    This depends on your personal circumstance and...
# 3    Share your interest in continuous learning and...
# 4    Describe your work style based on your strengt...
# ..                                                 ...
# 494  When visualizing categorical data with a large...
# 495  Data visualization ethic refers to the ethical...
# 496  Techniques for visualizing network or graph da...
# 497  Data reduction in visualization refers to the ...
# 498  When visualizing data with outlier or extreme ...
#
# [499 rows x 1 columns]

# %%
df3.to_csv('/content/ans-ds.csv', index=False)
