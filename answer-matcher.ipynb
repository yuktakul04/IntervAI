# %%
import csv

# %%
def load_answers_from_csv(file_path):
    answers = {}
    with open(file_path, 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            question = row[0]
            answer = row[1]
            answers[question] = answer
    return answers

# %%
def calculate_accuracy(given_answers, correct_answers):
    num_correct = 0
    total = len(given_answers)
    for question, given_answer in given_answers.items():
        correct_answer = correct_answers.get(question)
        if correct_answer and given_answer.lower() == correct_answer.lower():
            num_correct += 1
    accuracy = (num_correct / total) * 100
    return accuracy

# %%
def test_matching_accuracy(given_answers_file, correct_answers_file):
    # Step 1: Load the correct answers from the CSV file
    correct_answers = load_answers_from_csv(correct_answers_file)

    # Step 2: Load the given answers
    given_answers = load_answers_from_csv(given_answers_file)

    # Step 3: Calculate accuracy
    accuracy = calculate_accuracy(given_answers, correct_answers)

    return accuracy

# %%
given_answers_file = '/content/answers.csv'
correct_answers_file = '/content/new-dataset.csv'
accuracy = test_matching_accuracy(given_answers_file, correct_answers_file)
print(f"Matching Accuracy: {accuracy}%")
# Out:
# Matching Accuracy: 0.0%

# %%
'''similar but new code'''

# %%
import csv

def load_answers_from_csv(file_path):
    answers = {}
    with open(file_path, 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            question = row[0]
            answer = row[1]
            answers[question] = answer
    return answers

def get_user_answers(questions):
    user_answers = {}
    for question in questions:
        user_answer = input(question + " ")
        user_answers[question] = user_answer
    return user_answers

def calculate_accuracy(given_answers, correct_answers):
    num_correct = 0
    total = len(given_answers)
    for question, given_answer in given_answers.items():
        correct_answer = correct_answers.get(question)
        if correct_answer and given_answer.lower() == correct_answer.lower():
            num_correct += 1
    accuracy = (num_correct / total) * 100
    return accuracy

def test_matching_accuracy(given_answers_file, correct_answers_file):
    correct_answers = load_answers_from_csv(correct_answers_file)
    given_answers = get_user_answers(correct_answers.keys())
    accuracy = calculate_accuracy(given_answers, correct_answers)
    return accuracy

given_answers_file = 'path/to/your/given_answers.csv'
correct_answers_file = '/content/new-dataset.csv'
accuracy = test_matching_accuracy(given_answers_file, correct_answers_file)
print(f"Matching Accuracy: {accuracy}%")

questions = [
    "Question 1: What is your name?",
    "Question 2: How old are you?",
    "Question 3: What is your favorite color?",
    # Add more questions here
]

given_answers = get_user_answers(questions)
# Out:
# 99 generaL

# %%
# !pip install fuzzywuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import csv
import numpy as np
from fuzzywuzzy import fuzz

def load_answers_from_csv(file_path):
    answers = {}
    with open(file_path, 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            question = row[0]
            answer = row[1]
            answers[question] = answer
    return answers

def calculate_accuracy(spoken_text, answers):
    accuracy_scores = []
    for question, answer in answers.items():
        similarity_score = fuzz.ratio(spoken_text, answer)
        accuracy_scores.append(similarity_score)
    accuracy = np.mean(accuracy_scores)
    return accuracy

spoken_text = "python is a high level language"
file_path = '/content/new-dataset.csv'

answers = load_answers_from_csv(file_path)
accuracy = calculate_accuracy(spoken_text, answers)

print(f"Conversion Accuracy: {accuracy}%")
# Out:
# Conversion Accuracy: 19.714285714285715%
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
